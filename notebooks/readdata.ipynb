# %%
import pandas as pd
import json

from collections import Counter, defaultdict
import numpy as np
import os
from tqdm import tqdm

import fitz
import re

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

from gensim.utils import simple_preprocess
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.test.utils import get_tmpfile
from gensim.utils import tokenize

from sklearn.metrics.pairwise import cosine_similarity

tqdm.pandas()

# %% [markdown]
# ### Testing

# %%
doc = fitz.open('corpus1/TrainTestSet/Trainset/data/868212__concatenated.pdf')
# doc[98].get_text('blocks')

# %% [markdown]
# ### Get header and footer functions

# %%
def get_header(page):
    try:
        doc = page.get_text('blocks')
        if not doc:
            return ''

        doc_length = page.rect[-1]
        max_header = doc_length*.095
        texts = []

        for text in doc:
            if text[1] <= max_header and text[1] != 0 and 'image' not in text[4]:
                texts.append(text[4])
        
        return re.sub('\n',' ', ' '.join([str(item) for item in texts]))
        
    except:
        return ''

get_header(doc[51])
# Out:
# ''

# %%
def get_footer(page):
    try:
        doc = page.get_text('blocks')
        if not doc:
            return ''
    
        doc_length = page.rect[-1]
        max_footer = doc_length*.905
        texts = []

        for text in doc:
            if text[1] >= max_footer and text[1] != 0 and 'image' not in text[4]:
                texts.append(text[4])

        
        return re.sub('\n',' ', ' '.join([str(item) for item in texts]))

    except:
        return ''
        
get_footer(doc[51])
# Out:
# '16 Jaarrapportage Aanpak Radicalisering en Polarisatie 2016 '

# %% [markdown]
# ### Function to check whether the font of a page differs from the previous page(s)

# %%
def font_diff1(df, font):
    is_diff = []
    
    _1 = df.shift(1)
    _2 = df.shift(2)
    _3 = df.shift(3)

    for i in tqdm(range(len(df))):
        a = df.iloc[i][font]
        b = set()

        if i == 0:
            b = set()

        elif i == 1:
            b.update(_1.iloc[i][font])

        elif i == 2:
            b.update(_1.iloc[i][font])
            b.update(_2.iloc[i][font])

        else:
            b.update(_1.iloc[i][font])
            b.update(_2.iloc[i][font])
            b.update(_3.iloc[i][font])

        if len(b) == 0:
            is_diff.append(-1)

        elif a == {'none'} or b == {'none'}:
            is_diff.append(0)

        elif bool(a & b):
            is_diff.append(1)

        else:
            is_diff.append(-1)
            
    return is_diff


def font_diff2(df, font):
    is_diff = [-1]
    _1 = df.shift()

    for i in tqdm(range(1, len(df))):
        a = df.iloc[i][font]
        b = _1.iloc[i][font]

        if a == {'none'} or b == {'none'}:
            is_diff.append(0)

        elif bool(a & b):
            is_diff.append(1)


        else:
            is_diff.append(-1)

    return is_diff

def font_diff3(df):
    it = iter(range(1,len(df)))
    diff = [-1]

    for i in tqdm(it):
        a = df.iloc[i]['fonts']
        b = df.iloc[i-1]['fonts']

        if a == {'none'}:
            j = i
            skips = 1
            j+=1
            diff.append(0)

            while df.iloc[j]['fonts'] == {'none'}:
                diff.append(0)
                j+=1
                skips+=1
            
            a = df.iloc[j]['fonts']

            if bool(a&b):
                diff.append(1)
            
            else:
                diff.append(-1)
            

            for _ in range(skips):
                i = next(it)

        else:
            if bool(a&b):
                diff.append(1)
            

            else:
                diff.append(-1)

    return diff

# %%
def crop_diff(df):
    is_diff = [-1]
    _1 = df.shift()
    
    for i in tqdm(range(1, len(df))):
        a = (df.iloc[i]['cropbox_x'], df.iloc[i]['cropbox_y'])
        b = (_1.iloc[i]['cropbox_x'], _1.iloc[i]['cropbox_y'])
        
        if a == b:
            is_diff.append(1)
        else:
            is_diff.append(-1)

    return is_diff

# %%
def simple_tokenize(text, _stopwords):
    return [token for token in simple_preprocess(text) if token not in _stopwords]

# %%
def preprocess_text(text, _stopwords, stemmer):
    if pd.isnull(text):
        return []
    tokens = simple_tokenize(text, _stopwords)
    stemmed = [stemmer.stem(word) for word in tokens]
    
    return stemmed

# %% [markdown]
# ### Create dataframe with features containing all concatenated training documents

# %%
pd.set_option('display.max_columns', 40)

def read(corpus_no):
    path = 'corpus'+str(corpus_no)+'/TrainTestSet/Trainset/data/'
    a = defaultdict(list)
    with open('corpus'+str(corpus_no)+'/TrainTestSet/Trainset/Doclengths_of_the_individual_docs_TRAIN.json', 'r') as f:
        data = json.load(f)

    for r, d, f in os.walk(path):
        if '.ipynb_checkpoints' in d:
            d.remove('.ipynb_checkpoints')
        for file in tqdm(f):
            doc = fitz.open(r+file)
            
            for page in doc:

                a['file_name'].append(file.split('__')[0])
                a['page'].append(page.number+1)

                cropbox = page.rect[-2:]
                a['cropbox_x'].append(cropbox[0])
                a['cropbox_y'].append(cropbox[1])

                a['text'].append(page.get_text())

                fonts = set()
                for font in page.get_fonts():
                    fonts.add(font[3].split('+')[0])
                    
                if fonts:
                    a['fonts'].append(fonts)
                else:
                    a['fonts'].append({'none'})

                if page.get_text() == '':
                    a['isImage'].append(1)

                else:
                    a['isImage'].append(0)

                header = get_header(page)
                footer = get_footer(page)
                a['header'].append(header)
                a['footer'].append(footer)
                
            # break

    df = pd.DataFrame(a)

    # # display(df)

    ### Labeling ###
    print('labeling')
    df['label'] = 0
    for file in tqdm(df['file_name'].unique()):
        split = 1
        for i in data[file]:
            df.loc[(df['file_name'] == file) & (df['page'] == split), 'label'] = 1
            split+=i
    ################
    
    ### Join OCR ###
    ocr = pd.read_csv('corpus'+str(corpus_no)+'/TrainTestSet/Trainset/ocred_text.csv',index_col = 0)
    ocr.rename(columns = {'name':'file_name'}, inplace = True)
    ocr['file_name'] = ocr['file_name'].apply(lambda x: x.split('__')[0])
    df = df.merge(ocr, on = ['file_name','page'], how = 'left')
    ################
    
    # ### Drop things ###
    # # df = drop_images(df)
    # ###################
    
    ### Tokenization & Cleaning ###
    print('cleaning')
    _stopwords = stopwords.words('dutch')
    stemmer = SnowballStemmer('dutch')

    df['preprocessed_text'] = df['text_y'].progress_apply(lambda x: preprocess_text(x, _stopwords, stemmer))   
    df['text_y_cleaned'] = df['preprocessed_text'].apply(lambda x: ' '.join([str(item) for item in x]))
    ####################
    
    # ### Drop things 2 ###
    # # df.dropna(subset=['text_y_fasttext_cleaned'], inplace = True)
    # #####################
            
    # ### Differences ###
    print('calculating differences')
    # df['font_diff1'] = font_diff1(df,'fonts')
    # df['font_diff2'] = font_diff2(df,'fonts')
    df['crop_diff'] = crop_diff(df)
    df['isLastPage'] = np.nan_to_num(df['label'].shift(-1).values, nan = 1)
    df['font_diff3'] = font_diff3(df)
    # ###################

    c = df.columns
    df = df[['full_name', 'file_name', 'page', 'cropbox_x', 'cropbox_y',
       'text_x', 'text_y', 'text_y_cleaned', 'header', 'footer', 'fonts',
       'preprocessed_text','isImage','isLastPage','crop_diff','font_diff3', 'label']]
    
    print([d for d in c if d not in df.columns])
    df.to_csv('dfs/c'+str(corpus_no)+'.csv')
    # # display(df)

    return df

df = read(2)
# df[['file_name','page','text_y','header','footer','label']][:200]
# Out:
#   7%|▋         | 8/113 [02:04<27:17, 15.60s/it]

# %%
c1 = pd.read_csv('dfs/c1.csv',index_col = 0)
c2 = pd.read_csv('dfs/c2.csv',index_col = 0)

# %%
from ast import literal_eval
c1['fonts'] = c1['fonts'].apply(literal_eval)
c2['fonts'] = c2['fonts'].apply(literal_eval)

# %%
pd.set_option('display.max_rows', 1000)
c2[['page','fonts','font_diff3','crop_diff','label']][:200]
# Out:
#      page                                              fonts  font_diff3  \
# 0       1                           {WEMLVK, PNWTQT, JPXFWQ}          -1
# 1       2                           {WEMLVK, PNWTQT, JPXFWQ}           1
# 2       3                                             {none}           0
# 3       4                   {WVHQSO, XNGBWX, JJUKDK, IQEYES}          -1
# 4       5                                             {none}           0
# 5       6                                             {none}           0
# 6       7                                             {none}           0
# 7       8                                             {none}           0
# 8       9                                             {none}           0
# 9      10                                             {none}           0
# 10     11                                             {none}           0
# 11     12                                             {none}           0
# 12     13                                             {none}           0
# 13     14                                             {none}           0
# 14     15                                             {none}           0
# 15     16                                             {none}           0
# 16     17                                             {none}           0
# 17     18                                             {none}           0
# 18     19                                             {none}           0
# 19     20                                             {none}           0
# 20     21                                             {none}           0
# 21     22                                             {none}           0
# 22     23                                             {none}           0
# 23     24                                             {none}           0
# 24     25                                             {none}           0
# 25     26                                             {none}           0
# 26     27                                             {none}           0
# 27     28                                             {none}           0
# 28     29                                             {none}           0
# 29     30                                             {none}           0
# 30     31                                             {none}           0
# 31     32                                             {none}           0
# 32     33                                             {none}           0
# 33     34                                             {none}           0
# 34     35                                             {none}           0
# 35     36                                             {none}           0
# 36     37                                             {none}           0
# 37     38                                             {none}           0
# 38     39                                             {none}           0
# 39     40                                             {none}           0
# 40     41                                             {none}           0
# 41     42                                             {none}           0
# 42     43                                             {none}           0
# 43     44                                             {none}           0
# 44     45                                             {none}           0
# 45     46                                             {none}           0
# 46     47                                             {none}           0
# 47     48                                             {none}           0
# 48     49                                             {none}           0
# 49     50                                             {none}           0
# 50     51                                             {none}           0
# 51     52                                             {none}           0
# 52     53                                             {none}           0
# 53     54                                             {none}           0
# 54     55                                             {none}           0
# 55     56                                             {none}           0
# 56     57                                             {none}           0
# 57     58                                             {none}           0
# 58     59                                             {none}           0
# 59     60                                             {none}           0
# 60     61                                             {none}           0
# 61     62                                             {none}           0
# 62     63                                             {none}           0
# 63     64                                             {none}           0
# 64     65                                             {none}           0
# 65     66                                             {none}           0
# 66     67                                             {none}           0
# 67     68                                             {none}           0
# 68     69                                             {none}           0
# 69     70                                             {none}           0
# 70     71                                             {none}           0
# 71     72                                             {none}           0
# 72     73                                           {ZRFZYF}          -1
# 73     74                                             {none}           0
# 74     75                                             {none}           0
# 75     76                                             {none}           0
# 76     77                                             {none}           0
# 77     78                                             {none}           0
# 78     79                                             {none}           0
# 79     80                                             {none}           0
# 80     81                                             {none}           0
# 81     82                                             {none}           0
# 82     83                                             {none}           0
# 83     84                                             {none}           0
# 84     85                                             {none}           0
# 85     86                                             {none}           0
# 86     87                                             {none}           0
# 87     88                                             {none}           0
# 88     89                                             {none}           0
# 89     90                                   {YHYRIS, PVXDCZ}          -1
# 90     91           {ZHEWHP, RNWEBG, ZVQUDV, GXQVTB, JVAEKQ}          -1
# 91     92                           {AKXRQL, FMJFTV, SSEHTI}          -1
# 92     93                                             {none}           0
# 93     94                                           {FAAAAH}          -1
# 94      1           {DNCFXB, HMDMAT, PNWTQT, DPDAGW, QYOIAB}          -1
# 95      2                   {HMDMAT, DPDAGW, JLSUUU, PNWTQT}           1
# 96      3                                             {none}           0
# 97      4                           {DPDAGW, HMDMAT, PNWTQT}           1
# 98      5                           {VNZQXL, CUUQAF, GMTXSU}          -1
# 99      6                   {BCDEEE, BCDFEE, GUKEQH, BCDHEE}          -1
# 100     7                           {BCDEEE, BCDFEE, AZZPJY}           1
# 101     8                                           {SMTIQT}          -1
# 102     9                           {BCDFEE, BCDHEE, NQIAEO}          -1
# 103    10                           {BCDGEE, BCDFEE, OQSOXV}           1
# 104    11                           {YNXDHC, BCDEEE, BCDFEE}           1
# 105    12                           {BCDEEE, YTJLTC, BCDFEE}           1
# 106    13                   {IHEEOI, BCDEEE, BCDFEE, BCDGEE}           1
# 107    14                                           {BCDEEE}           1
# 108    15                   {BCDEEE, FDQWVI, BCDFEE, BCDGEE}           1
# 109    16                                   {TRBBSR, VMUMBS}          -1
# 110    17                   {BCDEEE, BCDHEE, ANTSAT, BCDGEE}          -1
# 111    18                                           {MVBFAZ}          -1
# 112    19                           {BCDEEE, EQHINK, BCDGEE}          -1
# 113    20                                           {TVUPGW}          -1
# 114    21                                           {UXYLWF}          -1
# 115    22                   {GNQNXC, BCDEEE, BCDFEE, BCDGEE}          -1
# 116    23                           {BCDEEE, VJSCKC, BCDGEE}           1
# 117    24                                           {WFGIHG}          -1
# 118    25                           {WSPWAQ, BCDEEE, BCDGEE}          -1
# 119    26                           {JGYMML, BCDEEE, BCDFEE}           1
# 120    27                           {URKSPF, BCDEEE, BCDFEE}           1
# 121    28                                   {BCDEEE, TCKREL}           1
# 122    29                                   {BCDEEE, BCDGEE}           1
# 123    30                                             {none}           0
# 124    31  {BCDIEE, BCDEEE, BCDLEE, BCDFEE, BCDHEE, BCDGE...           1
# 125    32  {BCDIEE, BCDEEE, BCDKEE, BCDFEE, BCDHEE, BCDGE...           1
# 126    33                   {BCDEEE, BCDFEE, BCDHEE, BCDGEE}           1
# 127    34                   {BCDEEE, BCDFEE, BCDHEE, BCDGEE}           1
# 128    35                   {BCDEEE, BCDFEE, BCDHEE, BCDGEE}           1
# 129    36  {BCDEEE, BCDKEE, BCDMEE, BCDFEE, BCDHEE, BCDGE...           1
# 130     1                                   {BCDEEE, BCDFEE}           1
# 131     2                           {BCDEEE, BCDFEE, BCDGEE}           1
# 132     3           {BCDIEE, BCDEEE, BCDHEE, BCDGEE, BCDFEE}           1
# 133     1                            {InvisibleMonospacePdf}          -1
# 134     2                            {InvisibleMonospacePdf}           1
# 135     3                            {InvisibleMonospacePdf}           1
# 136     4                            {InvisibleMonospacePdf}           1
# 137     5                            {InvisibleMonospacePdf}           1
# 138     6                            {InvisibleMonospacePdf}           1
# 139     7                            {InvisibleMonospacePdf}           1
# 140     8                            {InvisibleMonospacePdf}           1
# 141     9                            {InvisibleMonospacePdf}           1
# 142    10                            {InvisibleMonospacePdf}           1
# 143    11                            {InvisibleMonospacePdf}           1
# 144    12                            {InvisibleMonospacePdf}           1
# 145    13                            {InvisibleMonospacePdf}           1
# 146    14                            {InvisibleMonospacePdf}           1
# 147    15                            {InvisibleMonospacePdf}           1
# 148    16                            {InvisibleMonospacePdf}           1
# 149    17                            {InvisibleMonospacePdf}           1
# 150    18                            {InvisibleMonospacePdf}           1
# 151    19                            {InvisibleMonospacePdf}           1
# 152    20                            {InvisibleMonospacePdf}           1
# 153    21                            {InvisibleMonospacePdf}           1
# 154    22                            {InvisibleMonospacePdf}           1
# 155    23                            {InvisibleMonospacePdf}           1
# 156    24                            {InvisibleMonospacePdf}           1
# 157    25                            {InvisibleMonospacePdf}           1
# 158    26                            {InvisibleMonospacePdf}           1
# 159    27                            {InvisibleMonospacePdf}           1
# 160    28                            {InvisibleMonospacePdf}           1
# 161    29                            {InvisibleMonospacePdf}           1
# 162    30                            {InvisibleMonospacePdf}           1
# 163    31                            {InvisibleMonospacePdf}           1
# 164    32                            {InvisibleMonospacePdf}           1
# 165    33                            {InvisibleMonospacePdf}           1
# 166    34                            {InvisibleMonospacePdf}           1
# 167    35                            {InvisibleMonospacePdf}           1
# 168    36                            {InvisibleMonospacePdf}           1
# 169    37                            {InvisibleMonospacePdf}           1
# 170    38                            {InvisibleMonospacePdf}           1
# 171    39                            {InvisibleMonospacePdf}           1
# 172    40                            {InvisibleMonospacePdf}           1
# 173    41                            {InvisibleMonospacePdf}           1
# 174    42                            {InvisibleMonospacePdf}           1
# 175    43                            {InvisibleMonospacePdf}           1
# 176    44                            {InvisibleMonospacePdf}           1
# 177    45                            {InvisibleMonospacePdf}           1
# 178    46                            {InvisibleMonospacePdf}           1
# 179    47                            {InvisibleMonospacePdf}           1
# 180    48                            {InvisibleMonospacePdf}           1
# 181    49                            {InvisibleMonospacePdf}           1
# 182    50                            {InvisibleMonospacePdf}           1
# 183    51                            {InvisibleMonospacePdf}           1
# 184    52                            {InvisibleMonospacePdf}           1
# 185    53                            {InvisibleMonospacePdf}           1
# 186    54                            {InvisibleMonospacePdf}           1
# 187    55                            {InvisibleMonospacePdf}           1
# 188    56                            {InvisibleMonospacePdf}           1
# 189    57                            {InvisibleMonospacePdf}           1
# 190    58                            {InvisibleMonospacePdf}           1
# 191    59                            {InvisibleMonospacePdf}           1
# 192    60                            {InvisibleMonospacePdf}           1
# 193    61                            {InvisibleMonospacePdf}           1
# 194    62                            {InvisibleMonospacePdf}           1
# 195    63                            {InvisibleMonospacePdf}           1
# 196    64                            {InvisibleMonospacePdf}           1
# 197    65                            {InvisibleMonospacePdf}           1
# 198    66                            {InvisibleMonospacePdf}           1
# 199    67                            {InvisibleMonospacePdf}           1
#
#      crop_diff  label
# 0           -1      1
# 1            1      0
# 2            1      0
# 3           -1      1
# 4           -1      1
# 5           -1      1
# 6            1      0
# 7            1      0
# 8           -1      1
# 9            1      0
# 10           1      0
# 11           1      0
# 12           1      0
# 13           1      0
# 14           1      0
# 15           1      0
# 16          -1      1
# 17           1      0
# 18           1      1
# 19           1      0
# 20           1      0
# 21           1      0
# 22           1      0
# 23           1      0
# 24           1      0
# 25           1      0
# 26           1      0
# 27           1      0
# 28          -1      1
# 29           1      0
# 30          -1      0
# 31          -1      0
# 32          -1      0
# 33           1      0
# 34           1      0
# 35           1      0
# 36          -1      1
# 37          -1      0
# 38          -1      1
# 39          -1      1
# 40          -1      0
# 41          -1      1
# 42          -1      1
# 43          -1      0
# 44          -1      1
# 45          -1      1
# 46           1      0
# 47           1      0
# 48           1      0
# 49          -1      1
# 50          -1      1
# 51          -1      0
# 52           1      0
# 53           1      0
# 54           1      0
# 55           1      0
# 56           1      1
# 57          -1      1
# 58           1      1
# 59           1      1
# 60          -1      1
# 61          -1      1
# 62          -1      1
# 63          -1      1
# 64          -1      0
# 65          -1      1
# 66          -1      1
# 67          -1      1
# 68          -1      1
# 69          -1      1
# 70          -1      1
# 71          -1      1
# 72          -1      1
# 73          -1      1
# 74          -1      1
# 75           1      1
# 76          -1      1
# 77           1      1
# 78          -1      1
# 79          -1      1
# 80           1      1
# 81          -1      1
# 82           1      0
# 83           1      0
# 84           1      1
# 85           1      0
# 86           1      0
# 87          -1      0
# 88           1      0
# 89          -1      1
# 90           1      1
# 91          -1      1
# 92          -1      1
# 93           1      0
# 94          -1      1
# 95           1      0
# 96           1      0
# 97           1      0
# 98          -1      1
# 99          -1      1
# 100          1      1
# 101          1      1
# 102          1      0
# 103          1      0
# 104          1      1
# 105          1      1
# 106          1      0
# 107          1      0
# 108          1      0
# 109          1      0
# 110          1      0
# 111          1      0
# 112          1      0
# 113          1      0
# 114          1      0
# 115          1      0
# 116          1      0
# 117          1      0
# 118          1      0
# 119          1      0
# 120          1      0
# 121          1      0
# 122          1      0
# 123          1      1
# 124          1      0
# 125          1      0
# 126          1      0
# 127          1      0
# 128          1      0
# 129          1      0
# 130         -1      1
# 131         -1      1
# 132          1      0
# 133         -1      1
# 134          1      0
# 135          1      0
# 136          1      0
# 137          1      0
# 138          1      0
# 139          1      0
# 140          1      0
# 141          1      0
# 142          1      0
# 143          1      0
# 144          1      0
# 145          1      0
# 146          1      0
# 147          1      0
# 148          1      0
# 149          1      0
# 150          1      0
# 151          1      0
# 152          1      0
# 153          1      0
# 154          1      0
# 155          1      0
# 156          1      0
# 157          1      0
# 158          1      0
# 159          1      0
# 160          1      0
# 161          1      0
# 162          1      0
# 163          1      0
# 164          1      0
# 165          1      0
# 166          1      0
# 167          1      0
# 168          1      0
# 169          1      0
# 170          1      0
# 171          1      0
# 172          1      0
# 173          1      0
# 174          1      0
# 175          1      0
# 176          1      0
# 177          1      0
# 178          1      0
# 179          1      0
# 180          1      0
# 181          1      0
# 182          1      0
# 183          1      0
# 184          1      0
# 185          1      0
# 186          1      0
# 187          1      0
# 188          1      0
# 189          1      0
# 190          1      0
# 191          1      0
# 192          1      0
# 193          1      0
# 194          1      0
# 195          1      0
# 196          1      0
# 197          1      0
# 198          1      0
# 199          1      0
